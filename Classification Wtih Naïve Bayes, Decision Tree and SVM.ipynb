# %% [markdown]
# # Text Mining workshop to understand Naïve Bayes, Decision Tree and SVM

# %%
import pandas as pd
news=pd.read_table('r8-train-all-terms.txt',header=None,names = ["Class", "Text"])
news.head()
# Out:
#   Class                                               Text
# 0  earn  champion products ch approves stock split cham...
# 1   acq  computer terminal systems cpml completes sale ...
# 2  earn  cobanco inc cbco year net shr cts vs dlrs net ...
# 3  earn  am international inc am nd qtr jan oper shr lo...
# 4  earn  brown forman inc bfd th qtr net shr one dlr vs...

# %%
#Summarize the data by the news class
news.groupby('Class').describe()
# Out:
#           Text
#          count unique                                                top freq
# Class
# acq       1596   1591  nippon life seeking tie with u s securities ho...    2
# crude      253    245  opec defending dlr price subroto says indonesi...    2
# earn      2840   2835  kasler corp kasl st qtr jan net shr profit thr...    2
# grain       41     41  u s cabinet council set to mull farm issues th...    1
# interest   190    176  fed adds reserves via customer repurchases the...    3
# money-fx   206    195  sumita says bank will intervene if necessary b...    3
# ship       108    105  agency reports ships waiting at panama canal t...    3
# trade      251    239  yeutter sees u s japan verging on trade confli...    2

# %% [markdown]
# The data above is inbalaced. so we can take 3 categories

# %%
#Select a subset from the dataframe. (crude money-fx trade)
subnews=news[(news.Class=="trade")| (news.Class=='crude')|(news.Class=='money-fx') ]

# %%
subnews.groupby('Class').describe()
print(subnews.shape)
# Out:
# (710, 2)

# %% [markdown]
# Here we got the dimention

# %%
#Count the length of each document
length=subnews['Text'].apply(len)
subnews=subnews.assign(Length=length)
subnews.head()
# Out:
#     Class                                               Text  Length
# 15  trade  brazil anti inflation plan limps to anniversar...    1134
# 43  crude  diamond shamrock dia cuts crude prices diamond...     532
# 55  crude  opec may have to meet to firm prices analysts ...    2558
# 76  crude  texaco canada cuts crude prices canadian cts b...      76
# 77  crude  texaco canada txc lowers crude postings texaco...     344

# %%
#Plot the distribution of the document length for each category
import matplotlib.pyplot as plt
# %matplotlib inline
subnews.hist(column='Length',by='Class',bins=50)

plt.figure()

# %% [markdown]
# for Above histogram X = Length of the Documents Y = Frequency
# Most of the documents for Money-FX is around 1000. same for others. We can dig deeper

# %%
subnews.head()
# Out:
#     Class                                               Text  Length
# 15  trade  brazil anti inflation plan limps to anniversar...    1134
# 43  crude  diamond shamrock dia cuts crude prices diamond...     532
# 55  crude  opec may have to meet to firm prices analysts ...    2558
# 76  crude  texaco canada cuts crude prices canadian cts b...      76
# 77  crude  texaco canada txc lowers crude postings texaco...     344

# %%
#Define preprocessing function

import nltk
#nltk.download()
from nltk.corpus import stopwords
newstopwords=stopwords.words("English") + ['yuhao','the','is','it','may']
WNlemma = nltk.WordNetLemmatizer()


def pre_process(text):
    tokens = nltk.word_tokenize(text)
    tokens=[WNlemma.lemmatize(t) for t in tokens]
    tokens=[word for word in tokens if word not in newstopwords]
    #data in list now. join back as documents
    text_after_process=" ".join(tokens)
    return(text_after_process)

# %%
#Apply the function on each document
subnews['Text'] = subnews['Text'].apply(pre_process)

# %%
subnews.head()
# Out:
#     Class                                               Text  Length
# 15  trade  brazil anti inflation plan limp anniversary in...    1134
# 43  crude  diamond shamrock dia cut crude price diamond s...     532
# 55  crude  opec meet firm price analyst opec forced meet ...    2558
# 76  crude  texaco canada cut crude price canadian ct bbl ...      76
# 77  crude  texaco canada txc lower crude posting texaco c...     344

# %%
length=subnews['Text'].apply(len)
subnews=subnews.assign(Length=length)

# %%
subnews.head()
# Out:
#     Class                                               Text  Length
# 15  trade  brazil anti inflation plan limp anniversary in...     839
# 43  crude  diamond shamrock dia cut crude price diamond s...     410
# 55  crude  opec meet firm price analyst opec forced meet ...    1793
# 76  crude  texaco canada cut crude price canadian ct bbl ...      69
# 77  crude  texaco canada txc lower crude posting texaco c...     287

# %%
#split the data into training and testing
#seting Random seed - every time we split the data, we will get different data.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(subnews.Text, subnews.Class, test_size=0.33, random_state=12)

# %%
#Create dtm by using word occurence

from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer( )

X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape
# Out:
# (475, 6033)

# %% [markdown]
# Row = documents, column = Values

# %%
count_vect.get_feature_names()
# Out:
# ['aam',
#  'ab',
#  'abal',
#  'abandon',
#  'abdel',
#  'abdelaziz',
#  'abdul',
#  'abdulaziz',
#  'abdullah',
#  'abide',
#  'abiding',
#  'ability',
#  'able',
#  'abroad',
#  'abrupt',
#  'absolutely',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'abu',
#  'abundant',
#  'abuse',
#  'academic',
#  'acccounts',
#  'accelerate',
#  'accelerated',
#  'accelerating',
#  'accentuating',
#  'accept',
#  'acceptable',
#  'accepted',
#  'accepting',
#  'access',
#  'accession',
#  'accident',
#  'acclerated',
#  'accommodating',
#  'accommodation',
#  'accomodations',
#  'accompanied',
#  'accompany',
#  'accompanying',
#  'accomplished',
#  'accomplishment',
#  'accord',
#  'accordance',
#  'according',
#  'account',
#  'accountable',
#  'accounted',
#  'accounting',
#  'accredited',
#  'accrued',
#  'accuse',
#  'accused',
#  'achieve',
#  'achieved',
#  'achieves',
#  'acid',
#  'acknowledged',
#  'acknowledging',
#  'acknowleged',
#  'acquire',
#  'acquired',
#  'acquiring',
#  'acquisition',
#  'acre',
#  'acreage',
#  'acrimony',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'activation',
#  'active',
#  'actively',
#  'activity',
#  'actual',
#  'actually',
#  'adam',
#  'adana',
#  'adapingthe',
#  'adapt',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'addressed',
#  'addressing',
#  'adequate',
#  'adhere',
#  'adhered',
#  'adherence',
#  'adhering',
#  'adjust',
#  'adjusted',
#  'adjustment',
#  'administered',
#  'administration',
#  'administrator',
#  'adminsitration',
#  'admission',
#  'admit',
#  'admitted',
#  'adopt',
#  'adopted',
#  'adopting',
#  'adoption',
#  'advance',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'adverse',
#  'adversely',
#  'adverserial',
#  'advised',
#  'adviser',
#  'advises',
#  'advisory',
#  'advocate',
#  'advocated',
#  'aegean',
#  'aerial',
#  'aerospace',
#  'affair',
#  'affect',
#  'affected',
#  'affecting',
#  'affiliate',
#  'affirmation',
#  'afford',
#  'afl',
#  'africa',
#  'african',
#  'afternoon',
#  'ag',
#  'agcny',
#  'aged',
#  'ageing',
#  'agency',
#  'agenda',
#  'agent',
#  'aggravated',
#  'aggravation',
#  'aggregate',
#  'aggressive',
#  'aggressively',
#  'agip',
#  'ago',
#  'agree',
#  'agreed',
#  'agreeement',
#  'agreeing',
#  'agreement',
#  'agrees',
#  'agricultural',
#  'agriculture',
#  'agrio',
#  'agro',
#  'aguarico',
#  'ahc',
#  'ahead',
#  'ahmed',
#  'aid',
#  'aide',
#  'aided',
#  'aim',
#  'aimed',
#  'air',
#  'airbus',
#  'aircraft',
#  'airport',
#  'aizawa',
#  'akiman',
#  'akzo',
#  'al',
#  'alan',
#  'alarmed',
#  'alaska',
#  'alaskan',
#  'alberta',
#  'albertans',
#  'alcudiai',
#  'alert',
#  'alfred',
#  'algeria',
#  'algerian',
#  'algiers',
#  'ali',
#  'alick',
#  'align',
#  'alignment',
#  'alike',
#  'allegation',
#  'alleged',
#  'allegedly',
#  'alleges',
#  'allegiance',
#  'alleging',
#  'alleviated',
#  'allied',
#  'allocate',
#  'allocated',
#  'allocating',
#  'allocation',
#  'allotted',
#  'allow',
#  'allowable',
#  'allowance',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'alter',
#  'alteration',
#  'altered',
#  'alternative',
#  'although',
#  'altogether',
#  'aluminium',
#  'alvite',
#  'always',
#  'amazon',
#  'ambassador',
#  'ambitious',
#  'amend',
#  'amendment',
#  'amerada',
#  'america',
#  'american',
#  'amid',
#  'amman',
#  'ammendments',
#  'ammonia',
#  'amoco',
#  'among',
#  'amortisation',
#  'amount',
#  'amounted',
#  'ample',
#  'amstutz',
#  'amtorg',
#  'analysis',
#  'analyst',
#  'anatolian',
#  'anba',
#  'anchor',
#  'andean',
#  'andes',
#  'anger',
#  'angered',
#  'angrily',
#  'angry',
#  'anita',
#  'ankara',
#  'anne',
#  'annex',
#  'anniversary',
#  'annouce',
#  'announce',
#  'announced',
#  'announcement',
#  'announces',
#  'announcing',
#  'annoyed',
#  'annual',
#  'annually',
#  'anonymous',
#  'another',
#  'answer',
#  'anti',
#  'anticipated',
#  'anticipating',
#  'anticipation',
#  'antidumping',
#  'antonio',
#  'anwar',
#  'anxious',
#  'anybody',
#  'anything',
#  'anytime',
#  'anyway',
#  'aomi',
#  'apart',
#  'apea',
#  'apholte',
#  'api',
#  'apolonio',
#  'apparel',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appealed',
#  'appealing',
#  'appear',
#  'appearance',
#  'appeared',
#  'appears',
#  'apple',
#  'applicant',
#  'application',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appointed',
#  'appointing',
#  'appoints',
#  'appreciate',
#  'appreciated',
#  'appreciation',
#  'approach',
#  'approached',
#  'appropriate',
#  'appropriately',
#  'appropriation',
#  'approval',
#  'approve',
#  'approved',
#  'approves',
#  'approving',
#  'approximately',
#  'april',
#  'aps',
#  'aqazadeh',
#  'aquitaine',
#  'arab',
#  'arabe',
#  'arabia',
#  'arabian',
#  'aramco',
#  'aramid',
#  'arauca',
#  'arbitraging',
#  'arbitrary',
#  'arbroath',
#  'arc',
#  'archer',
#  'archie',
#  'architect',
#  'arco',
#  'area',
#  'argue',
#  'argued',
#  'argues',
#  'arguing',
#  'argument',
#  'arifin',
#  'arisen',
#  'arising',
#  'arizona',
#  'arm',
#  'armacost',
#  'armed',
#  'arnold',
#  'around',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'arrears',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arsenal',
#  'article',
#  'artificially',
#  'arturo',
#  'asadi',
#  'ashland',
#  'asia',
#  'asian',
#  'ask',
#  'asked',
#  'asking',
#  'aspect',
#  'aspen',
#  'aspirant',
#  'ass',
#  'assam',
#  'assembled',
#  'asserted',
#  'assertion',
#  'assessing',
#  'assessment',
#  'asset',
#  'assign',
#  'assigned',
#  'assigns',
#  'assist',
#  'assistance',
#  'assistant',
#  'assisting',
#  'associate',
#  'associated',
#  'association',
#  'assumed',
#  'assuming',
#  'assumption',
#  'assurance',
#  'assure',
#  'assured',
#  'assuring',
#  'athabasca',
#  'athens',
#  'atlantic',
#  'atmosphere',
#  'attached',
#  'attack',
#  'attacked',
#  'attain',
#  'attaka',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attend',
#  'attendance',
#  'attending',
#  'attends',
#  'attention',
#  'attitude',
#  'attract',
#  'attractive',
#  'attributable',
#  'attributed',
#  'aturo',
#  'au',
#  'auction',
#  'audio',
#  'august',
#  'augusta',
#  'auspex',
#  'austerity',
#  'australasian',
#  'australia',
#  'australian',
#  'austria',
#  'austrian',
#  'authorised',
#  'authoritative',
#  'authority',
#  'authorized',
#  'auto',
#  'autobiography',
#  'automatically',
#  'automobile',
#  'autonomous',
#  'autumn',
#  'availability',
#  'available',
#  'avalanche',
#  'average',
#  'averaged',
#  'averaging',
#  'avert',
#  'averted',
#  'aviation',
#  'avoid',
#  'avoidance',
#  'avoided',
#  'await',
#  'award',
#  'awarded',
#  'aware',
#  'away',
#  'ayal',
#  'ayala',
#  'aymah',
#  'baath',
#  'bache',
#  'back',
#  'backed',
#  'background',
#  'backing',
#  'bad',
#  'bae',
#  'baghdad',
#  'bahrain',
#  'bailey',
#  'baker',
#  'balance',
#  'balanced',
#  'balancing',
#  'balao',
#  'baldrige',
#  'ball',
#  'balladur',
#  'ban',
#  'bancaire',
#  'banco',
#  'band',
#  'bandwagon',
#  'bangladesh',
#  'bank',
#  'banker',
#  'banking',
#  'bankruptcy',
#  'banned',
#  'banque',
#  'banquet',
#  'baptiste',
#  'bar',
#  'barber',
#  'barclay',
#  'barclays',
#  'barents',
#  'bargaining',
#  'barney',
#  'barred',
#  'barrel',
#  'barrier',
#  'barring',
#  'barter',
#  'bartering',
#  'base',
#  'based',
#  'baseless',
#  'basic',
#  'basically',
#  'basin',
#  'basis',
#  'basket',
#  'bass',
#  'bassiouni',
#  'bata',
#  'battle',
#  'battlefield',
#  'bay',
#  'bbl',
#  'bcf',
#  'beach',
#  'beacon',
#  'bear',
#  'bearish',
#  'beat',
#  'beaten',
#  'beaubien',
#  'became',
#  'becker',
#  'become',
#  'becoming',
#  'beef',
#  'beer',
#  'began',
#  'begin',
#  'begining',
#  'beginning',
#  'begun',
#  'behalf',
#  'behaviour',
#  'behind',
#  'beirut',
#  'belgian',
#  'belgium',
#  'belgo',
#  'belgolux',
#  'belief',
#  'believe',
#  'believed',
#  'belkacem',
#  'belligerent',
#  'belongs',
#  'benbow',
#  'benchmark',
#  'beneficial',
#  'beneficiary',
#  'benefit',
#  'benefitted',
#  'benefitting',
#  'bentsen',
#  'berlin',
#  'berne',
#  'berre',
#  'beset',
#  'best',
#  'bethesda',
#  'better',
#  'betwen',
#  'beyond',
#  'bfr',
#  'biannual',
#  'bias',
#  'bid',
#  'bidder',
#  'bidding',
#  'big',
#  'bigger',
#  'biggest',
#  'bijan',
#  'bilateral',
#  'bill',
#  'billion',
#  'bind',
#  'binding',
#  'bipartisan',
#  'bipolar',
#  'birthday',
#  'bit',
#  'bitter',
#  'bitterly',
#  'black',
#  'blamed',
#  'blaming',
#  'bleak',
#  'blend',
#  'bleu',
#  'bloated',
#  'bloc',
#  'block',
#  'blocked',
#  'blocking',
#  'blohm',
#  'blood',
#  'bloodbath',
#  'blow',
#  'bludgeon',
#  'blue',
#  'board',
#  'boat',
#  'bob',
#  'body',
#  'boelkow',
#  'bogged',
#  'boiling',
#  'bold',
#  'bolivar',
#  'bolster',
#  'bombed',
#  'bombing',
#  'bonanza',
#  'bond',
#  'bonker',
#  'bonn',
#  'bonny',
#  'bonus',
#  'book',
#  'boom',
#  'boomerang',
#  'booming',
#  'boone',
#  'boost',
#  'boosted',
#  'boosting',
#  'border',
#  'bordering',
#  'borne',
#  'borrower',
#  'borrowing',
#  'bottom',
#  'bought',
#  'bound',
#  'bouy',
#  'bow',
#  'boycott',
#  'boycotted',
#  'bp',
#  'bpd',
#  'br',
#  'bracho',
#  'bradstreet',
#  'brake',
#  'branch',
#  'brancho',
#  'branded',
#  'brasil',
#  'brasileiro',
#  'brasilia',
#  'brass',
#  'brazil',
#  'brazilian',
#  'breach',
#  'breached',
#  'break',
#  'breakdown',
#  'breaking',
#  'breakneck',
#  'breakthrough',
#  'breather',
#  'breathing',
#  'brent',
#  'brian',
#  'bridge',
#  'bridged',
#  'brief',
#  'briefing',
#  'briefly',
#  'brien',
#  'brightest',
#  'bring',
#  'bringing',
#  'brings',
#  'brink',
#  'brinkmanship',
#  'britain',
#  'britian',
#  'british',
#  'brkn',
#  'broad',
#  'broadcasting',
#  'broadened',
#  'broader',
#  'broadly',
#  'brody',
#  'broke',
#  'broken',
#  'broker',
#  'brother',
#  'brought',
#  'bruce',
#  'brussels',
#  'buchanan',
#  'buckler',
#  'budget',
#  'budgetary',
#  'budgeted',
#  'budgeting',
#  'buena',
#  'bugdet',
#  'buhindi',
#  'build',
#  'building',
#  'built',
#  'bukhoosh',
#  'bulk',
#  'bull',
#  'bulletin',
#  'bullish',
#  'bullishness',
#  'bumper',
#  'bundesbank',
#  'buoyant',
#  'burden',
#  'burdened',
#  'bureau',
#  'burgan',
#  'burned',
#  'burst',
#  'bury',
#  'bus',
#  'business',
#  'businessman',
#  'businessmen',
#  'butcher',
#  'buy',
#  'buyer',
#  'buying',
#  'byrd',
#  'bywater',
#  'cabinet',
#  'cable',
#  'cacex',
#  'caf',
#  'cairo',
#  'calculated',
#  'calculating',
#  'calculation',
#  'calendar',
#  'calgary',
#  'california',
#  'caljet',
#  'call',
#  'called',
#  'calling',
#  'calm',
#  'caltex',
#  'cambist',
#  'cambridge',
#  'camdessus',
#  'came',
#  'camp',
#  'campaign',
#  'canada',
#  'canadaina',
#  'canadian',
#  'cancel',
#  'cancelled',
#  'cancelling',
#  'cancer',
#  'cano',
#  'canot',
#  'canterra',
#  'canvas',
#  'cap',
#  'capable',
#  'capacity',
#  'capel',
#  'capital',
#  'captive',
#  'car',
#  'caracas',
#  'carbone',
#  'carbozulia',
#  'cardenas',
#  'care',
#  'career',
#  'careful',
#  'carefully',
#  'cargill',
#  'cargo',
#  'caribbean',
#  'carl',
#  'carlos',
#  'carlsson',
#  'carlucci',
#  'carney',
#  'carole',
#  'carried',
#  'carry',
#  'carrying',
#  'cartel',
#  'carter',
#  'case',
#  'casey',
#  'cash',
#  'cassette',
#  'category',
#  'caught',
#  'cause',
#  'caused',
#  'causing',
#  'cautioned',
#  'cautious',
#  'cawl',
#  'cayambe',
#  'cease',
#  'ceiling',
#  'census',
#  'cent',
#  'center',
#  'central',
#  'centralled',
#  'centrally',
#  'centre',
#  'centred',
#  'century',
#  'cepe',
#  'cera',
#  'cereal',
#  'ceremony',
#  'certain',
#  'certainly',
#  'certainty',
#  'certificate',
#  'certification',
#  'cfr',
#  'chacin',
#  'chain',
#  'chair',
#  'chairman',
#  'chalabi',
#  'chalaby',
#  'challenge',
#  'challenged',
#  'chamber',
#  'champlin',
#  'chance',
#  'chancellor',
#  'change',
#  'changed',
#  'changing',
#  'channel',
#  'channon',
#  'chao',
#  'characterized',
#  'charge',
#  'charged',
#  'charging',
#  'chartered',
#  'cheap',
#  'cheaper',
#  'cheating',
#  'check',
#  'checked',
#  'chemical',
#  'chen',
#  'chernobyl',
#  'chevron',
#  'chicago',
#  'chicken',
#  'chief',
#  'chiefly',
#  'chien',
#  'childhood',
#  'chile',
#  'china',
#  'chinese',
#  'chip',
#  'chipmaker',
#  'chipmakers',
#  'chirac',
#  'chocolate',
#  'choice',
#  'choke',
#  'chona',
#  'choose',
#  'choppy',
#  'chosen',
#  'christi',
#  'chronic',
#  'chunk',
#  'chv',
#  'cie',
#  'cif',
#  'cigarette',
#  'cio',
#  'circuit',
#  'circulation',
#  'circumstance',
#  'cited',
#  'citgo',
#  'citibank',
#  'citing',
#  'citizen',
#  'citrus',
#  'city',
#  'civil',
#  'claim',
#  'claimed',
#  'clarifies',
#  'clarify',
#  'clarifying',
#  'clark',
#  'class',
#  'claude',
#  'clause',
#  'clayton',
#  'clear',
#  'clearcut',
#  'cleared',
#  'clearing',
#  'clearly',
#  'clercq',
#  'clever',
#  'client',
#  'climate',
#  'climb',
#  'climbed',
#  'close',
#  'closed',
#  'closely',
#  'closer',
#  'closest',
#  'closing',
#  'closure',
#  'clouded',
#  'clout',
#  'club',
#  'cme',
#  'cmte',
#  'cnooc',
#  'cnp',
#  'co',
#  'coal',
#  'coalition',
#  'coast',
#  'coastal',
#  'coffee',
#  'coin',
#  'coincide',
#  'coking',
#  'cold',
#  'colder',
#  'collaborating',
#  'collapse',
#  'collapsed',
#  'colleague',
#  'collective',
#  'collectively',
#  'cologne',
#  'colombia',
#  'colombian',
#  'colon',
#  'colorado',
#  'columbians',
#  'combat',
#  'combination',
#  'combined',
#  'combining',
#  'come',
#  'comeback',
#  'comecon',
#  'comfortable',
#  'coming',
#  'command',
#  'comment',
#  'commented',
#  'commenting',
#  'commerce',
#  'commercial',
#  'commission',
#  'commissioner',
#  ...]

# %%
dtm1 = pd.DataFrame(X_train_counts.toarray().transpose(), index = count_vect.get_feature_names())
dtm1=dtm1.transpose()
dtm1.head()
dtm1.to_csv('dtm1.csv',sep=',')

# %% [markdown]
# # Building a Naïve Bayes Model

# %%
#Create dtm by using Term Frequency. 
#Divide the number of occurrences of each word in a document 
#by the total number of words in the document: 
#these new features are called tf for Term Frequencies
#If set use_idf=True, which mean create dtm by using tf_idf

from sklearn.feature_extraction.text import TfidfTransformer
tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_train_tf.shape
# Out:
# (475, 6033)

# %%
#Building Modeling by using Naïve Bayes
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tf, y_train)

# %%
#Prediction on new documents
docs_new = ['Crude price is dropping ', 'rate is increasing']

X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tf_transformer.transform(X_new_counts)
#X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)
print(predicted)
# Out:
# ['crude' 'money-fx']

# %% [raw]
# 1)Convert to DTM
# 2)Normalize the DTM
# 3)Model Creation
#
# We can combine above 3 steps in to one step as pipeline. With Pipeline we can avoid some previous steps

# %%
#Build a pipeline: Combine multiple steps into one
from sklearn.pipeline import Pipeline
text_clf = Pipeline([('vect', CountVectorizer()),  
                     ('tfidf', TfidfTransformer()),
                      ('clf', MultinomialNB()),
                    ])

# %%
#Use pipeline to train the model
text_clf.fit(X_train,y_train )
# Out:
# Pipeline(steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...inear_tf=False, use_idf=True)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
#Test model accuracy
import numpy as np
from sklearn import metrics 
predicted = text_clf.predict(X_test)
#np.mean(predicted == y_test) 
print(metrics.confusion_matrix(y_test, predicted))
print(np.mean(predicted == y_test) )
# Out:
# [[76  1  2]
#  [ 1 63 16]
#  [ 0  0 76]]
# 0.914893617021

# %% [markdown]
# # Building a Decision Tree Model

# %% [raw]
# 1)Convert to DTM
# 2)Normalize the DTM
# 3)Classifier for DT
#
# First 2 steps same as NB model

# %%
#Decision Tree

from sklearn import tree
text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                      ('clf', tree.DecisionTreeClassifier())
                    ])
text_clf.fit(X_train, y_train) 
predicted = text_clf.predict(X_test)

print(metrics.confusion_matrix(y_test, predicted))
print(np.mean(predicted == y_test) )
# Out:
# [[73  5  1]
#  [ 2 74  4]
#  [ 1  4 71]]
# 0.927659574468

# %% [markdown]
# # Building a SVM Model

# %% [raw]
# 1)Convert to DTM
# 2)Normalize the DTM
# 3)Use Linear SVC
#
# First 2 steps same as NB model

# %%
#SVM
from sklearn import svm
from sklearn.svm import SVC

from sklearn.linear_model import SGDClassifier
text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer(use_idf=True)),
                      ('clf', svm.LinearSVC(C=1.0))
                    ])

# %%
text_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
predicted = text_clf.predict(X_test)
 
print(metrics.confusion_matrix(y_test, predicted))
print(np.mean(predicted == y_test) )
#y_test.value_counts()
# Out:
# [[78  1  0]
#  [ 0 74  6]
#  [ 1  1 74]]
# 0.96170212766

# %%
print(metrics.classification_report(y_test, predicted))
# Out:
#              precision    recall  f1-score   support
#
#       crude       0.99      0.99      0.99        79
#    money-fx       0.97      0.93      0.95        80
#       trade       0.93      0.97      0.95        76
#
# avg / total       0.96      0.96      0.96       235

# %%
import itertools
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
cnf_matrix = confusion_matrix(y_test, predicted)
plot_confusion_matrix(cnf_matrix, classes=['crude','money_fx','trade'],
                      title='Confusion matrix, without normalization')
plt.figure()
plt.show()
# Out:
# Confusion matrix, without normalization
# [[78  1  0]
#  [ 0 74  6]
#  [ 1  1 74]]

# %% [markdown]
# # Introduce the GridSearch Method

# %% [raw]
# Ideally gird search will look for best value combination with the list of values for ANY MODEL
#
# Here we are going to use GridSearch To get better 'C' Value for SVM and it will iteratively try with different C value.

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
                  'tfidf__use_idf': (True, False),
                   'clf__C': (1, 0.5, 0.3, 2),
                }

#text_clf = Pipeline([('vect', CountVectorizer()),
#                    ('tfidf', TfidfTransformer(use_idf=True)),
#                      ('clf', SGDClassifier(
#                                            alpha=1e-3 
#                                             ))
#                    ])

# %%
# If we give this parameter a value of -1, 
#grid search will detect how many cores are installed and uses them all:

gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1)
gs_clf = gs_clf.fit(X_train, y_train)
for param_name in sorted(parameters.keys()):
    print("%s: %r" % (param_name, gs_clf.best_params_[param_name]))
# Out:
# clf__C: 1
# tfidf__use_idf: True
